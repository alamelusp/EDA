# %%
import pandas as pd
df=pd.read_csv('titanic.csv')
df.head(70)
# Out:
#     PassengerId  Survived  Pclass  \
# 0           892         0       3
# 1           893         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# ..          ...       ...     ...
# 65          957         1       2
# 66          958         1       3
# 67          959         0       1
# 68          960         0       1
# 69          961         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 0                                    Kelly, Mr. James    male  34.5      0
# 1                    Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                           Myles, Mr. Thomas Francis    male  62.0      0
# 3                                    Wirz, Mr. Albert    male  27.0      0
# 4        Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# ..                                                ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df["Cabin"]=df["Cabin"].fillna(0)
df.isnull().sum()
# Out:
# PassengerId     0
# Survived        0
# Pclass          0
# Name            0
# Sex             0
# Age            86
# SibSp           0
# Parch           0
# Ticket          0
# Fare            1
# Cabin           0
# Embarked        0
# dtype: int64

# %%
df["Fare"]=df["Fare"].fillna(0)
df.isnull().sum()
# Out:
# PassengerId     0
# Survived        0
# Pclass          0
# Name            0
# Sex             0
# Age            86
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Cabin           0
# Embarked        0
# dtype: int64

# %%
df[df["Age"]==0.0].head(50)
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.isnull().sum()
# Out:
# PassengerId     0
# Survived        0
# Pclass          0
# Name            0
# Sex             0
# Age            86
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Cabin           0
# Embarked        0
# dtype: int64

# %%
df[df["Age"].isna()].head(50)
# Out:
#      PassengerId  Survived  Pclass  \
# 10           902         0       3
# 22           914         1       1
# 29           921         0       3
# 33           925         1       3
# 36           928         1       3
# 39           931         0       3
# 41           933         0       1
# 47           939         0       3
# 54           946         0       2
# 58           950         0       3
# 65           957         1       2
# 76           968         0       3
# 83           975         0       3
# 84           976         0       2
# 85           977         0       3
# 88           980         1       3
# 91           983         0       3
# 93           985         0       3
# 102          994         0       3
# 107          999         0       3
# 108         1000         0       3
# 111         1003         1       3
# 116         1008         0       3
# 121         1013         0       3
# 124         1016         0       3
# ...

# %%
df.loc[(df["Survived"].isin([0]))&
        (df["SibSp"].isin([0]))&
        (df["Cabin"].isin([0])),"Age"]="0.0"
df
df.isnull().sum()
# Out:
# PassengerId     0
# Survived        0
# Pclass          0
# Name            0
# Sex             0
# Age            39
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Cabin           0
# Embarked        0
# dtype: int64

# %%
df[df["SibSp"] == 0].head(30)
# Out:
#     PassengerId  Survived  Pclass  \
# 0           892         0       3
# 2           894         0       2
# 3           895         0       3
# 5           897         0       3
# 6           898         1       3
# 8           900         1       3
# 10          902         0       3
# 11          903         0       1
# 16          908         0       2
# 17          909         0       3
# 19          911         1       3
# 21          913         0       3
# 22          914         1       1
# 23          915         0       1
# 26          918         1       1
# 27          919         0       3
# 28          920         0       1
# 35          927         0       3
# 36          928         1       3
# 37          929         1       3
# 38          930         0       3
# 39          931         0       3
# 40          932         0       3
# 41          933         0       1
# 42          934         0       3
# 43          935         1       2
# ...

# %%
df[df["Survived"]==0].head(20)
# Out:
#     PassengerId  Survived  Pclass                             Name   Sex  \
# 0           892         0       3                 Kelly, Mr. James  male
# 2           894         0       2        Myles, Mr. Thomas Francis  male
# 3           895         0       3                 Wirz, Mr. Albert  male
# 5           897         0       3       Svensson, Mr. Johan Cervin  male
# 7           899         0       2     Caldwell, Mr. Albert Francis  male
# 9           901         0       3          Davies, Mr. John Samuel  male
# 10          902         0       3                 Ilieff, Mr. Ylio  male
# 11          903         0       1       Jones, Mr. Charles Cresson  male
# 13          905         0       2             Howard, Mr. Benjamin  male
# 16          908         0       2                Keane, Mr. Daniel  male
# 17          909         0       3                Assaf, Mr. Gerios  male
# 20          912         0       1           Rothschild, Mr. Martin  male
# ...

# %%
df.loc[(df["Pclass"].isin([3]))&
        (df["SibSp"].isin([0]))&
        (df["Cabin"].isin([0])),"Age"]="0.0"
df
df.isnull().sum()
# Out:
# PassengerId     0
# Survived        0
# Pclass          0
# Name            0
# Sex             0
# Age            23
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Cabin           0
# Embarked        0
# dtype: int64

# %%
df[df["Age"].isna()].head(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 22           914         1       1
# 29           921         0       3
# 33           925         1       3
# 58           950         0       3
# 65           957         1       2
# 85           977         0       3
# 121         1013         0       3
# 127         1019         1       3
# 133         1025         0       3
# 146         1038         0       1
#
#                                                   Name     Sex  Age  SibSp  \
# 22                Flegenheim, Mrs. Alfred (Antoinette)  female  NaN      0
# 29                                   Samaan, Mr. Elias    male  NaN      2
# 33   Johnston, Mrs. Andrew G (Elizabeth Lily" Watson)"  female  NaN      1
# 58                           Davison, Mr. Thomas Henry    male  NaN      1
# 65   Corey, Mrs. Percy C (Mary Phyllis Elizabeth Mi...  female  NaN      0
# 85                                  Khalil, Mr. Betros    male  NaN      1
# ...

# %%
df.loc[(df["Pclass"].isin([3]))&
        (df["SibSp"].isin([1]))&
        (df["Cabin"].isin([0])),"Age"]="0.0"
df
df.isnull().sum()
# Out:
# PassengerId     0
# Survived        0
# Pclass          0
# Name            0
# Sex             0
# Age            10
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Cabin           0
# Embarked        0
# dtype: int64

# %%
df[df["Age"].isna()].head(7)
# Out:
#      PassengerId  Survived  Pclass  \
# 22           914         1       1
# 65           957         1       2
# 146         1038         0       1
# 168         1060         1       1
# 188         1080         1       3
# 288         1180         0       3
# 301         1193         0       2
#
#                                                   Name     Sex  Age  SibSp  \
# 22                Flegenheim, Mrs. Alfred (Antoinette)  female  NaN      0
# 65   Corey, Mrs. Percy C (Mary Phyllis Elizabeth Mi...  female  NaN      0
# 146                        Hilliard, Mr. Herbert Henry    male  NaN      0
# 168  Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...  female  NaN      0
# 188                                    Sage, Miss. Ada  female  NaN      8
# 288                            Mardirosian, Mr. Sarkis    male  NaN      0
# 301                                Malachard, Mr. Noel    male  NaN      0
#
#      Parch        Ticket     Fare  Cabin Embarked
# ...

# %%
df.loc[(df["Pclass"].isin([3]))&
        (df["SibSp"].isin([2]))&
        (df["Cabin"].isin([0])),"Age"]="0.0"
df
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            7
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df[df["Age"].isna()].head(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 22           914         1       1
# 65           957         1       2
# 146         1038         0       1
# 168         1060         1       1
# 188         1080         1       3
#
#                                                   Name     Sex  Age  SibSp  \
# 22                Flegenheim, Mrs. Alfred (Antoinette)  female  NaN      0
# 65   Corey, Mrs. Percy C (Mary Phyllis Elizabeth Mi...  female  NaN      0
# 146                        Hilliard, Mr. Herbert Henry    male  NaN      0
# 168  Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...  female  NaN      0
# 188                                    Sage, Miss. Ada  female  NaN      8
#
#      Parch        Ticket     Fare Cabin Embarked
# 22       0      PC 17598  31.6833     0        S
# 65       0  F.C.C. 13534  21.0000     0        S
# 146      0         17463  51.8625   E46        S
# 168      0         17770  27.7208     0        C
# 188      2      CA. 2343  69.5500     0        S

# %%
df.loc[(df["Pclass"].isin([1]))&
        (df["SibSp"].isin([0]))&
        (df["Cabin"].isin([0])),"Age"]="0.0"
df
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            5
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df[df["Age"].isna()].head(9)
# Out:
#      PassengerId  Survived  Pclass  \
# 65           957         1       2
# 146         1038         0       1
# 188         1080         1       3
# 288         1180         0       3
# 301         1193         0       2
#
#                                                   Name     Sex  Age  SibSp  \
# 65   Corey, Mrs. Percy C (Mary Phyllis Elizabeth Mi...  female  NaN      0
# 146                        Hilliard, Mr. Herbert Henry    male  NaN      0
# 188                                    Sage, Miss. Ada  female  NaN      8
# 288                            Mardirosian, Mr. Sarkis    male  NaN      0
# 301                                Malachard, Mr. Noel    male  NaN      0
#
#      Parch        Ticket     Fare  Cabin Embarked
# 65       0  F.C.C. 13534  21.0000      0        S
# 146      0         17463  51.8625    E46        S
# 188      2      CA. 2343  69.5500      0        S
# 288      0          2655   7.2292  F E46        C
# ...

# %%
df.loc[(df["Pclass"].isin([1]))&
        (df["Parch"].isin([2]))&
        (df["Survived"].isin([1])),"Age"]="0.0"
df
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            2
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df[df["Age"].isna()].head(11)
# Out:
#      PassengerId  Survived  Pclass  \
# 65           957         1       2
# 188         1080         1       3
#
#                                                   Name     Sex  Age  SibSp  \
# 65   Corey, Mrs. Percy C (Mary Phyllis Elizabeth Mi...  female  NaN      0
# 188                                    Sage, Miss. Ada  female  NaN      8
#
#      Parch        Ticket   Fare Cabin Embarked
# 65       0  F.C.C. 13534  21.00     0        S
# 188      2      CA. 2343  69.55     0        S

# %%
df.loc[(df["Pclass"].isin([2]))&
        (df["Embarked"]=="S")&
        (df["Survived"].isin([1])),"Age"]="0.0"
df
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64
